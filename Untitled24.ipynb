# %% [markdown]
# <a href="https://colab.research.google.com/github/VeenaShep07/DA-Project123/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set the dataframe
gdp_df = pd.read_csv("GDP (nominal) per Capita.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15516/4083122914.py in <cell line: 0>()
#       1 # set the dataframe
# ----> 2 gdp_df = pd.read_csv("GDP (nominal) per Capita.csv")
#
# NameError: name 'pd' is not defined

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-a90b3127-db02-4918-aa6a-d9ad19b9df1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a90b3127-db02-4918-aa6a-d9ad19b9df1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
# set the dataframe
gdp_df = pd.read_csv("GDP (nominal) per Capita.csv")

# %%
gdp_df.head()
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
# 3           4           Ireland    Europe        114581      2023
# 4           5           Bermuda  Americas             0         0
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021
# 3              100172            2021       101109    2021
# 4              114090            2021       112653    2021

# %%
gdp_clean_df = gdp_df.dropna()

# %%
gdp_clean_df.head()   #returns the first few rows that are clean
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
# 3           4           Ireland    Europe        114581      2023
# 4           5           Bermuda  Americas             0         0
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021
# 3              100172            2021       101109    2021
# 4              114090            2021       112653    2021

# %%
# Are there any missing values left in the whole DataFrame?
gdp_clean_df.isna().values.any()
# Out:
# np.False_

# %%
# How many missing values per column?
gdp_clean_df.isna().sum()
# Out:
# Unnamed: 0            0
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64

# %% [markdown]
# Or,

# %%
# missing values in each column
gdp_df.isnull().sum()
# Out:
# Unnamed: 0            0
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64

# %% [markdown]
# .isna() and .isnull() are exact aliases in pandas; they do precisely the same thing.
# isna() = "is this value Not Available.

# %%
#Total missing values in dataframe
gdp_df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Remove any rows that contain missing values... # We did in class
gdp_clean_df = gdp_df.dropna()
